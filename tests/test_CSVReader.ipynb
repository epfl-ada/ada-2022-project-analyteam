# %%
from ingestion import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
client, cluster = dask_init()
csv_reader = CSVReader()
cluster
# Out:
# /home/farouk/anaconda3/envs/py3-9/lib/python3.9/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35083 instead
#   warnings.warn(
# Task exception was never retrieved
# future: <Task finished name='Task-1021' coro=<Client._gather.<locals>.wait() done, defined at /home/farouk/anaconda3/envs/py3-9/lib/python3.9/site-packages/distributed/client.py:2002> exception=AllExit()>
# Traceback (most recent call last):
#   File "/home/farouk/anaconda3/envs/py3-9/lib/python3.9/site-packages/distributed/client.py", line 2011, in wait
#     raise AllExit()
# distributed.client.AllExit
# LocalCluster(b7c75bc7, 'tcp://127.0.0.1:46861', workers=4, threads=8, memory=7.66 GiB)

# %%
df = csv_reader.lazy_extract("./Data/BeerAdvocate/beers.csv")
df = df.drop(columns="beer_name")
df.head(1_000_000)
# Out:
#         beer_id  brewery_id                         brewery_name  \
# 0        166064       39912               Abdysh-Ata (Абдыш Ата)
# 1        166065       39912               Abdysh-Ata (Абдыш Ата)
# 2        166066       39912               Abdysh-Ata (Абдыш Ата)
# 3        166067       39912               Abdysh-Ata (Абдыш Ата)
# 4        166063       39912               Abdysh-Ata (Абдыш Ата)
# ...         ...         ...                                  ...
# 280818    19139         885  Summit Station Restaurant & Brewery
# 280819    19140         885  Summit Station Restaurant & Brewery
# 280820    19146         885  Summit Station Restaurant & Brewery
# 280821     2805         885  Summit Station Restaurant & Brewery
# 280822    19148         885  Summit Station Restaurant & Brewery
#
#                          style  nbr_ratings  nbr_reviews   avg  ba_score  \
# 0              Euro Pale Lager            0            0   NaN       NaN
# ...

# %%
df = csv_reader.extract("./Data/BeerAdvocate/beers.csv")
df = df.drop(columns="beer_name")
df.head(1_000_000)
# Out:
#         beer_id  brewery_id                         brewery_name  \
# 0        166064       39912               Abdysh-Ata (Абдыш Ата)
# 1        166065       39912               Abdysh-Ata (Абдыш Ата)
# 2        166066       39912               Abdysh-Ata (Абдыш Ата)
# 3        166067       39912               Abdysh-Ata (Абдыш Ата)
# 4        166063       39912               Abdysh-Ata (Абдыш Ата)
# ...         ...         ...                                  ...
# 280818    19139         885  Summit Station Restaurant & Brewery
# 280819    19140         885  Summit Station Restaurant & Brewery
# 280820    19146         885  Summit Station Restaurant & Brewery
# 280821     2805         885  Summit Station Restaurant & Brewery
# 280822    19148         885  Summit Station Restaurant & Brewery
#
#                          style  nbr_ratings  nbr_reviews   avg  ba_score  \
# 0              Euro Pale Lager            0            0   NaN       NaN
# ...
