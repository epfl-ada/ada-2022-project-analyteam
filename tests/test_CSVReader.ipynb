# %%
from ingestion import CSVReader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_reader = CSVReader()

# %%
df = csv_reader.lazy_extract("./Data/BeerAdvocate/beers.csv")
df = df.drop(columns="beer_name")
df.head(100000)
# Out:
#        beer_id  brewery_id                           brewery_name  \
# 0       166064       39912                 Abdysh-Ata (Абдыш Ата)
# 1       166065       39912                 Abdysh-Ata (Абдыш Ата)
# 2       166066       39912                 Abdysh-Ata (Абдыш Ата)
# 3       166067       39912                 Abdysh-Ata (Абдыш Ата)
# 4       166063       39912                 Abdysh-Ata (Абдыш Ата)
# ...        ...         ...                                    ...
# 99995    47365        9823  Downtown Joe's American Bar And Grill
# 99996    47362        9823  Downtown Joe's American Bar And Grill
# 99997   113689        9823  Downtown Joe's American Bar And Grill
# 99998    35614        9823  Downtown Joe's American Bar And Grill
# 99999   201822        9823  Downtown Joe's American Bar And Grill
#
#                                      style  nbr_ratings  nbr_reviews   avg  \
# 0                          Euro Pale Lager            0            0   NaN
# 1                          Euro Pale Lager            0            0   NaN
# 2                          Euro Pale Lager            0            0   NaN
# 3                          Euro Pale Lager            0            0   NaN
# 4                          Euro Pale Lager            0            0   NaN
# ...                                    ...          ...          ...   ...
# 99995  Extra Special / Strong Bitter (ESB)            1            1  4.76
# 99996       American Double / Imperial IPA           12            3  4.04
# 99997                          Schwarzbier            1            0  3.50
# 99998  Extra Special / Strong Bitter (ESB)            5            2  3.73
# 99999              American Pale Ale (APA)            1            0  3.71
#
#        ba_score  bros_score  abv  avg_computed  zscore  \
# 0           NaN         NaN  4.7           NaN     NaN
# 1           NaN         NaN  3.8           NaN     NaN
# 2           NaN         NaN  4.8           NaN     NaN
# 3           NaN         NaN  4.0           NaN     NaN
# 4           NaN         NaN  4.5           NaN     NaN
# ...         ...         ...  ...           ...     ...
# 99995       NaN         NaN  NaN      4.760000     NaN
# 99996      85.0         NaN  NaN      4.101667     NaN
# 99997       NaN         NaN  NaN      3.500000     NaN
# 99998       NaN         NaN  NaN      3.656000     NaN
# 99999       NaN         NaN  NaN      3.710000     NaN
#
#        nbr_matched_valid_ratings  avg_matched_valid_ratings
# 0                              0                        NaN
# 1                              0                        NaN
# 2                              0                        NaN
# 3                              0                        NaN
# 4                              0                        NaN
# ...                          ...                        ...
# 99995                          0                        NaN
# 99996                          0                        NaN
# 99997                          0                        NaN
# 99998                          0                        NaN
# 99999                          0                        NaN
#
# [100000 rows x 14 columns]

# %%
df = csv_reader.extract("./Data/BeerAdvocate/beers.csv")
df = df.drop(columns="beer_name")
df.head(100000)
# Out:
#        beer_id  brewery_id                           brewery_name  \
# 0       166064       39912                 Abdysh-Ata (Абдыш Ата)
# 1       166065       39912                 Abdysh-Ata (Абдыш Ата)
# 2       166066       39912                 Abdysh-Ata (Абдыш Ата)
# 3       166067       39912                 Abdysh-Ata (Абдыш Ата)
# 4       166063       39912                 Abdysh-Ata (Абдыш Ата)
# ...        ...         ...                                    ...
# 99995    47365        9823  Downtown Joe's American Bar And Grill
# 99996    47362        9823  Downtown Joe's American Bar And Grill
# 99997   113689        9823  Downtown Joe's American Bar And Grill
# 99998    35614        9823  Downtown Joe's American Bar And Grill
# 99999   201822        9823  Downtown Joe's American Bar And Grill
#
#                                      style  nbr_ratings  nbr_reviews   avg  \
# 0                          Euro Pale Lager            0            0   NaN
# 1                          Euro Pale Lager            0            0   NaN
# 2                          Euro Pale Lager            0            0   NaN
# 3                          Euro Pale Lager            0            0   NaN
# 4                          Euro Pale Lager            0            0   NaN
# ...                                    ...          ...          ...   ...
# 99995  Extra Special / Strong Bitter (ESB)            1            1  4.76
# 99996       American Double / Imperial IPA           12            3  4.04
# 99997                          Schwarzbier            1            0  3.50
# 99998  Extra Special / Strong Bitter (ESB)            5            2  3.73
# 99999              American Pale Ale (APA)            1            0  3.71
#
#        ba_score  bros_score  abv  avg_computed  zscore  \
# 0           NaN         NaN  4.7           NaN     NaN
# 1           NaN         NaN  3.8           NaN     NaN
# 2           NaN         NaN  4.8           NaN     NaN
# 3           NaN         NaN  4.0           NaN     NaN
# 4           NaN         NaN  4.5           NaN     NaN
# ...         ...         ...  ...           ...     ...
# 99995       NaN         NaN  NaN      4.760000     NaN
# 99996      85.0         NaN  NaN      4.101667     NaN
# 99997       NaN         NaN  NaN      3.500000     NaN
# 99998       NaN         NaN  NaN      3.656000     NaN
# 99999       NaN         NaN  NaN      3.710000     NaN
#
#        nbr_matched_valid_ratings  avg_matched_valid_ratings
# 0                              0                        NaN
# 1                              0                        NaN
# 2                              0                        NaN
# 3                              0                        NaN
# 4                              0                        NaN
# ...                          ...                        ...
# 99995                          0                        NaN
# 99996                          0                        NaN
# 99997                          0                        NaN
# 99998                          0                        NaN
# 99999                          0                        NaN
#
# [100000 rows x 14 columns]
