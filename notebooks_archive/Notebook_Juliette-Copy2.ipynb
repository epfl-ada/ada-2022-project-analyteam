# %%
import numpy as np
import pandas as pd

# %%
ratings_file_name = "./Data/ratings.txt"
reviews_file_name = "./Data/ratings.txt"
enc = 'utf-8'

# %%
columns = ["beer_name", "beer_id", "brewery_name", "brewery_id", "style", "abv", "date", "user_name", "user_id", "appearance", "aroma", "palate", "taste", "overall", "rating", "text"]
print(columns)
nb_features = len(columns)
print(nb_features)
# Out:
# ['beer_name', 'beer_id', 'brewery_name', 'brewery_id', 'style', 'abv', 'date', 'user_name', 'user_id', 'appearance', 'aroma', 'palate', 'taste', 'overall', 'rating', 'text']
# 16

# %%
i = 0

#r = np.empty((16,1))
r = []
for i in range(16):
    r.append([])

with open(ratings_file_name, encoding=enc) as file:
    for line in file:
        if i % 1000000 == 0:
            print(i)
        l = line.strip()
        for j in range(nb_features):
            if columns[j] in l[:12]:
                l = l.replace(columns[j]+": ","")
                r[j].append(l)
        i += 1
# Out:
# 1000000
# 2000000
# 3000000
# 4000000
# 5000000
# 6000000
# 7000000
# 8000000
# 9000000
# 10000000
# 11000000
# 12000000
# 13000000
# 14000000
# 15000000
# 16000000
# 17000000
# 18000000
# 19000000
# 20000000
# 21000000
# 22000000
# 23000000
# 24000000
# 25000000
# 26000000
# 27000000
# 28000000
# 29000000
# 30000000
# 31000000
# 32000000
# 33000000
# 34000000
# 35000000
# 36000000
# 37000000
# 38000000
# 39000000
# 40000000
# 41000000
# 42000000
# 43000000
# 44000000
# 45000000
# 46000000
# 47000000
# 48000000
# 49000000
# 50000000
# 51000000
# 52000000
# 53000000
# 54000000
# 55000000
# 56000000
# 57000000
# 58000000
# 59000000
# 60000000
# 61000000
# 62000000
# 63000000
# 64000000
# 65000000
# 66000000
# 67000000
# 68000000
# 69000000
# 70000000
# 71000000
# 72000000
# 73000000
# 74000000
# 75000000
# 76000000
# 77000000
# 78000000
# 79000000
# 80000000
# 81000000
# 82000000
# 83000000
# 84000000
# 85000000
# 86000000
# 87000000
# 88000000
# 89000000
# 90000000
# 91000000
# 92000000
# 93000000
# 94000000
# 95000000
# 96000000
# 97000000
# 98000000
# 99000000
# 100000000
# 101000000
# 102000000
# 103000000
# 104000000
# 105000000
# 106000000
# 107000000
# 108000000
# 109000000
# 110000000
# 111000000
# 112000000
# 113000000
# 114000000
# 115000000
# 116000000
# 117000000
# 118000000
# 119000000
# 120000000
# 121000000

# %%
lengths = []
for i in range(nb_features):
    print(columns[i])
    print(r[i][:100])
    lengths.append(len(r[i]))
    print(len(r[i]))
print(lengths)
# Out:
# beer_name
# ['33 Export (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Castel Beer (Gabon)', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Régab', 'Ards Bally Black Stout', 'Ards Bally Black Stout', 'Ards Bally Black Stout', 'Ards Bally Black Stout', 'Ards Bally Black Stout', 'Ards Bally Black Stout', 'Ards Belfast 366', 'Ards Bittles Christmas', 'Ards Bittles Citra Autumn Ale', 'Ards Cardy Man', 'Ards Hip Hop', 'Ards Pig Island Pale Ale', 'Ards Pig Island Pale Ale', 'Ards Pig Island Pale Ale', 'Ards Pig Island Pale Ale', 'Ards Rockin\x92 Goose', 'Ards Rockin\x92 Goose', 'Ards Rockin\x92 Goose', 'Ards Scrabo Gold', 'Ards Single Hop Nelson Sauvin Pale Ale', 'Ards Summer Ale', 'Bittles Aged Winter Ale', 'Bittles East Coast', 'Barrahooley Black IPA', 'Barrahooley Dry Stout', 'Barrahooley Pale Ale', 'Boundary / Brick / Ulster Exiles / Bullfinch Screwball', 'Boundary / Galway Bay Border Hopper (bretted)', 'Boundary / Galway Bay Border Hopper (bretted)', 'Boundary / Galway Bay Border Hopper (clean)', 'Boundary / Heaney Farmhouse No Coast', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Mad Hatter Milk Agitator', 'Boundary / Neill & Ross Adega', 'Boundary / Neill & Ross Adega', 'Boundary / Neill & Ross Adega', 'Boundary / Neill & Ross Adega', 'Boundary / Neill & Ross Adega', 'Boundary / Outland / Kinnegar / White Hag Pink Sunglasses', 'Boundary / Outland / Kinnegar / White Hag Pink Sunglasses', 'Boundary / Outland Pari Gagnant', 'Boundary / Outland Pari Gagnant', 'Boundary / Rascals Grand So', 'Boundary /Galway Bay A Berliner Vice #1', 'Boundary /Galway Bay A Berliner Vice #1', 'Boundary A Berliner Vice #2', 'Boundary A Berliner Vice #2', 'Boundary A Berliner Vice #2', 'Boundary A Berliner Vice #2', 'Boundary A Berliner Vice #2', 'Boundary A Berliner Vice #2', 'Boundary a Berliner Vice #3', 'Boundary a Berliner Vice #3', 'Boundary a Berliner Vice #3']
# 7122074
# beer_id
# ['410549', '105273', '105273', '105273', '105273', '105273', '105273', '105273', '105273', '105273', '105273', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '19445', '155699', '155699', '155699', '155699', '155699', '155699', '239097', '380930', '234108', '396830', '256772', '160664', '160664', '160664', '160664', '177517', '177517', '177517', '299091', '253129', '365410', '313889', '336216', '318125', '398981', '318126', '532818', '407134', '407134', '336169', '526627', '437440', '437440', '437440', '437440', '437440', '437440', '437440', '437440', '437440', '437440', '447427', '447427', '447427', '447427', '447427', '526629', '526629', '526630', '526630', '447432', '336168', '336168', '386909', '386909', '386909', '386909', '386909', '386909', '364610', '364610', '364610']
# 7122074
# brewery_name
# ['Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Sobraga', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Ards Brewing Co.', 'Barrahooley Craft Brewery', 'Barrahooley Craft Brewery', 'Barrahooley Craft Brewery', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary', 'Boundary']
# 7122074
# brewery_id
# ['3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '3198', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '13538', '22304', '22304', '22304', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818', '22818']
# 7122074
# style
# ['Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Pale Lager', 'Stout', 'Stout', 'Stout', 'Stout', 'Stout', 'Stout', 'Golden Ale/Blond Ale', 'Bitter', 'American Pale Ale', 'Stout', 'American Pale Ale', 'Bitter', 'Bitter', 'Bitter', 'Bitter', 'Irish Ale', 'Irish Ale', 'Irish Ale', 'Golden Ale/Blond Ale', 'American Pale Ale', 'Wheat Ale', 'English Strong Ale', 'American Pale Ale', 'Black IPA', 'Stout', 'American Pale Ale', 'India Pale Ale (IPA)', 'India Pale Ale (IPA)', 'India Pale Ale (IPA)', 'American Strong Ale', 'Imperial IPA', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Sour/Wild Ale', 'Sour/Wild Ale', 'Sour/Wild Ale', 'Sour/Wild Ale', 'Sour/Wild Ale', 'Zwickel/Keller/Landbier', 'Zwickel/Keller/Landbier', 'Saison', 'Saison', 'Session IPA', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse', 'Berliner Weisse']
# 7122085
# abv
# ['5.0', '5.2', '5.2', '5.2', '5.2', '5.2', '5.2', '5.2', '5.2', '5.2', '5.2', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.5', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.2', '4.2', '5.1', '4.2', '5.2', '5.2', '5.2', '5.2', '5.2', '4.4', '4.4', '4.4', '4.9', '5.8', '5.0', '6.0', '5.0', '4.85', '4.5', '4.85', '6.1', '8.8', '8.8', '7.2', '9.8', '4.1', '4.1', '4.1', '4.1', '4.1', '4.1', '4.1', '4.1', '4.1', '4.1', '7.0', '7.0', '7.0', '7.0', '7.0', '4.5', '4.5', '6.0', '6.0', '4.2', '2.7', '2.7', '1.9', '1.9', '1.9', '1.9', '1.9', '1.9', '2.7', '2.7', '2.7']
# 7122429
# date
# ['1461664800', '1487329200', '1466762400', '1451646000', '1445594400', '1444644000', '1444212000', '1430820000', '1401357600', '1374141600', '1245319200', '1487329200', '1438855200', '1438509600', '1438423200', '1438423200', '1438423200', '1438423200', '1436263200', '1429437600', '1374141600', '1352718000', '1347876000', '1346925600', '1346925600', '1346925600', '1346925600', '1346925600', '1346925600', '1346925600', '1245319200', '1215511200', '1204196400', '1204023600', '1203850800', '1209117600', '1202468400', '1088157600', '1429178400', '1427796000', '1421665200', '1380621600', '1371549600', '1321527600', '1385204400', '1449658800', '1382263200', '1455879600', '1409911200', '1382436000', '1371549600', '1385550000', '1339581600', '1385377200', '1342951200', '1340532000', '1416135600', '1397210400', '1444039200', '1424602800', '1432634400', '1438682400', '1456657200', '1456657200', '1500112800', '1459245600', '1459245600', '1432634400', '1498557600', '1484650800', '1476957600', '1476093600', '1476007200', '1475402400', '1473847200', '1471773600', '1470996000', '1470823200', '1470564000', '1487761200', '1486378800', '1483009200', '1483009200', '1483009200', '1499162400', '1498557600', '1500026400', '1498557600', '1475402400', '1446721200', '1432634400', '1477476000', '1470736800', '1469354400', '1469354400', '1469354400', '1468231200', '1452164400', '1452164400', '1452164400']
# 7123097
# user_name
# ['Manslow', 'MAGICuenca91', 'Sibarh', 'fombe89', 'kevnic2008', 'Beerhunter111', 'Erzengel', 'Manslow', 'Lowenbrau', 'seynie', 'Cletus', 'MAGICuenca91', 'GenDV138', 'nimbleprop', 'Iphonephan', 'solidfunk', 'radagast83', 'Travlr', 'fombe89', 'Manslow', 'seynie', 'fonefan', 'Kingink', 'Zita', 'Hansen', 'onystrom', 'Rasmus40', 'saxo', 'HenrikSoegaard', 'chrisv10', 'Cletus', 'lgklotet', 'rickgordon', 'oh6gdx', 'ante', 'omhper', 'jclaude', 'Nuffield', 'ciaranc', 'Rowlymo', 'Don2711', 'genegenie', 'kiwianer', 'Beersiveknown', 'Beersiveknown', 'Beersiveknown', 'Beersiveknown', 'Beersiveknown', 'Beersiveknown', 'Beersiveknown', 
. Pours a very sad, pale yellow color, no head. fizzy carbonation immediately. Interesting. Light candy, not too sweet. some corn. boring.', 'Can muled from the source by Maki, thanks very much! Clear bright golden yellow color, scant head. Aroma of wet cardboard. Taste is bland watery lager, inoffensive enough.', 'Botella, regalo familia. Color amarillo claro, aroma malta, carbonatacion alta', 'Butelka 0,66l alk 4,5% wypite w Gabonie w 2005r. Kolor jasnosłomkowy, piany brak, wodniste.Aromat cytrynowy, lekko kwaskowe, mocno gazowane.Smak niewyczuwalny, kwaskowe.Piwo afrykańskie typowe.', 'Light local beer of Gabon. Carbonation disappears quickly, watery taste. Easy to drink though.', 'Bottle. [ As my country rating # 134 on ratebeer ].[ Courtesy of The Aarhus Crew ]. Clear light to medium o ...
# 7122080
# [7122074, 7122074, 7122074, 7122074, 7122085, 7122429, 7123097, 7122074, 7122074, 7122074, 7125285, 7122082, 7125839, 7122074, 7122222, 7122080]

# %%
ratings_list = []
with open("./Data/ratings.txt", encoding='utf-8') as file:
    ratings_list = file.readlines()

# %%
print(len(ratings_list))

# %%
reviews_list = []
with open("./Data/reviews.txt", encoding='utf-8') as file:
    reviews_list = file.readlines()

# %%
print(len(reviews_list))
# Out:
# 121075258

# %%
print(ratings_list[:10])

# %%
import re
[m.start() for m in re.finditer('beer_name', 'test test test test')]

# %%
beer_names = []
beer_id = []


for r in ratings_list:
    if "beer_name" in r:
        beer_names.append(r[11:len(r)-1])
    elif "beer_id" in r:
        beer_id.append(r[9:len(r)-1])
print(beer_names)
print(beer_id)

# %%
with open("./Data/ratings.txt", encoding='utf-8') as file:
    ratings = ""
    for i in range(100):
        ratings += file.readline()

print("ratings : ", ratings)
# Out:
# ratings :  beer_name: 33 Export (Gabon)
# beer_id: 410549
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.0
# date: 1461664800
# user_name: Manslow
# user_id: 175852
# appearance: 2
# aroma: 4
# palate: 2
# taste: 4
# overall: 8
# rating: 2.00
# text: Puszka 0,33l dzięki Christoph . Kolor jasnozłoty, piana biała drobnoziarnista szybko opada. Aromat słodowy, lekko słodkie.Dość dobre.
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1487329200
# user_name: MAGICuenca91
# user_id: 442761
# appearance: 2
# aroma: 3
# palate: 2
# taste: 4
# overall: 8
# rating: 1.90
# text: Cerveza pale lager gabonesa. MÃ¡s floja que la Regab.Aroma escaso, apariencia pÃ¡lida, muy poco cuerpo y poco regusto en el paladar.Si algÃºn dÃ­a fuera a GabÃ³n pedirÃ­a una mÃ¡s para volver a probarla y el resto del tiempo pedirÃ­a la Regab sin duda, que tampoco es que sea nada del otro mundo, pero es superior a Ã©sta.
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1466762400
# user_name: Sibarh
# user_id: 288889
# appearance: 3
# aroma: 3
# palate: 2
# taste: 3
# overall: 5
# rating: 1.60
# text: Kolor- złoty, klarowny. Piana - drobna, średnio wysoka, nie trwała. Zapach - lekki słodowy. Smak - lekki słÃ³d i chmiel, lekki kwasek, lekka słodycz i goryczka
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1451646000
# user_name: fombe89
# user_id: 250510
# appearance: 4
# aroma: 3
# palate: 1
# taste: 2
# overall: 5
# rating: 1.50
# text: Botella, de GabÃ³n regalo familiar.31/01/2015Color amarillo, aromas y sabores a maiz, cuerpo medio
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1445594400
# user_name: kevnic2008
# user_id: 122778
# appearance: 2
# aroma: 4
# palate: 2
# taste: 4
# overall: 7
# rating: 1.90
# text: Many thanks for this beer to Erzengel. Pours light golden with medium head. Light bodied crisp taste with low carbonation. Sweet finish.
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1444644000
# user_name: Beerhunter111
# user_id: 227834
# appearance: 2
# aroma: 3
# palate: 2
# taste: 3
# overall: 9
# rating: 1.90

# %%
with open("./Data/reviews.txt", encoding='utf-8') as file:
    reviews = ""
    for i in range(100):
        reviews += file.readline()
print(reviews)
# Out:
# beer_name: 33 Export (Gabon)
# beer_id: 410549
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.0
# date: 1461664800
# user_name: Manslow
# user_id: 175852
# appearance: 2
# aroma: 4
# palate: 2
# taste: 4
# overall: 8
# rating: 2.00
# text: Puszka 0,33l dzięki Christoph . Kolor jasnozłoty, piana biała drobnoziarnista szybko opada. Aromat słodowy, lekko słodkie.Dość dobre.
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1487329200
# user_name: MAGICuenca91
# user_id: 442761
# appearance: 2
# aroma: 3
# palate: 2
# taste: 4
# overall: 8
# rating: 1.90
# text: Cerveza pale lager gabonesa. MÃ¡s floja que la Regab.Aroma escaso, apariencia pÃ¡lida, muy poco cuerpo y poco regusto en el paladar.Si algÃºn dÃ­a fuera a GabÃ³n pedirÃ­a una mÃ¡s para volver a probarla y el resto del tiempo pedirÃ­a la Regab sin duda, que tampoco es que sea nada del otro mundo, pero es superior a Ã©sta.
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1466762400
# user_name: Sibarh
# user_id: 288889
# appearance: 3
# aroma: 3
# palate: 2
# taste: 3
# overall: 5
# rating: 1.60
# text: Kolor- złoty, klarowny. Piana - drobna, średnio wysoka, nie trwała. Zapach - lekki słodowy. Smak - lekki słÃ³d i chmiel, lekki kwasek, lekka słodycz i goryczka
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1451646000
# user_name: fombe89
# user_id: 250510
# appearance: 4
# aroma: 3
# palate: 1
# taste: 2
# overall: 5
# rating: 1.50
# text: Botella, de GabÃ³n regalo familiar.31/01/2015Color amarillo, aromas y sabores a maiz, cuerpo medio
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1445594400
# user_name: kevnic2008
# user_id: 122778
# appearance: 2
# aroma: 4
# palate: 2
# taste: 4
# overall: 7
# rating: 1.90
# text: Many thanks for this beer to Erzengel. Pours light golden with medium head. Light bodied crisp taste with low carbonation. Sweet finish.
#
# beer_name: Castel Beer (Gabon)
# beer_id: 105273
# brewery_name: Sobraga
# brewery_id: 3198
# style: Pale Lager
# abv: 5.2
# date: 1444644000
# user_name: Beerhunter111
# user_id: 227834
# appearance: 2
# aroma: 3
# palate: 2
# taste: 3
# overall: 9
# rating: 1.90

# %%
print(reviews == ratings)
print(" nan " in reviews)
print(" nan " in ratings)
