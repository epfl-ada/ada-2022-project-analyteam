# %% [markdown]
# - beers per user : 373 seconds
# - std : 66 seconds
# - explorer score per user : 0.3 seconds per user
# - adventurer score per user : 0.09 s per user

# %%
import pandas as pd
import time

import categories as cat

# %%
ratings_parquets_path = 'RefinedData/BeerAdvocate//ratings.parquet'
beers_parquet_path = "RefinedData/BeerAdvocate/beers.parquet/"
users_parquet_path = "RefinedData/BeerAdvocate/users.parquet/"

# %%
t = time.time()
categorization = cat.Categorization(ratings_parquets_path, beers_parquet_path, users_parquet_path)
print("run time :",time.time()-t)
# Out:
# ratings loaded
# beers loaded
# users loaded
# ratings dated ( 334.2749857902527 )
# beers per user ( 345.99475717544556 )
# std ( 65.23974585533142 )
# run time : 748.02343583107

# %%
categorization.get_ratings_head()
# Out:
#                       date                   uid  bid  rating  dated_rating  \
# 111278 2003-03-17 11:00:00               mab.734    3    4.42      4.106667
# 99258  2002-11-20 11:00:00         morris729.996    3    3.88      3.950000
# 33704  2002-04-17 10:00:00               jason.3    3    4.02      4.020000
# 119242 2003-06-01 10:00:00    assurbanipaul.1754    4    3.45      3.652000
# 24941  2003-10-23 10:00:00       nerofiddled.526    4    4.10      3.726667
# 57874  2003-03-31 10:00:00        greencard.1619    4    2.67      3.310000
# 99261  2002-11-20 11:00:00         morris729.996    4    3.68      3.630000
# 33705  2002-04-05 10:00:00               jason.3    4    3.58      3.580000
# 75265  2004-06-22 10:00:00         bditty187.531    4    3.21      3.705000
# 55204  2005-03-09 11:00:00      allengarvin.7332    4    3.55      3.687778
# 67799  2003-04-25 10:00:00      atrumanimus.1074    4    4.88      3.702500
# 7457   2003-10-31 11:00:00    feloniousmonk.1022    4    4.07      3.775714
# 76005  2005-03-21 11:00:00       shapudding.4354    4    3.20      3.639000
# 35765  2011-11-17 11:00:00   merkurking16.637919    5    4.00      3.363220
# 36050  2011-08-16 10:00:00      smakawhat.204323    5    2.79      3.356676
# 371    2014-06-14 10:00:00       hohnbaum.788384    5    2.75      3.420771
# 53508  2013-02-06 11:00:00          mnash.700469    5    4.00      3.417341
# 41606  2005-04-11 10:00:00        arizcards.2240    5    3.92      3.425181
# 36042  2011-08-29 10:00:00         merkur.547728    5    3.18      3.352240
# 37127  2010-07-03 10:00:00      jeffjeff1.337702    5    3.38      3.365082
# 55066  2012-09-04 10:00:00        jgarvis.677033    5    3.50      3.410078
# 24813  2013-02-23 11:00:00    deanchs1980.717896    5    4.50      3.422772
# 53919  2013-01-06 11:00:00     stlouisram.332532    5    4.25      3.420604
# 35911  2011-11-06 11:00:00   arithmeticus.464859    5    2.70      3.354772
# 8505   2016-09-29 10:00:00  beerformuscle.109040    5    3.85      3.439392
# 21502  2012-10-29 11:00:00       vcoggins.691601    5    3.25      3.412056
# 33519  2012-04-02 10:00:00      hophead84.109437    5    3.30      3.389535
# 33766  2012-03-24 11:00:00          creez.663790    5    3.75      3.387188
# 31560  2012-07-20 10:00:00          jda007.63222    5    4.00      3.407660
# 35600  2011-11-26 11:00:00   thisladyluck.379254    5    4.00      3.379045
#
#         rank
# 111278     3
# 99258      2
# 33704      1
# 119242     5
# 24941      6
# 57874      3
# 99261      2
# 33705      1
# 75265      8
# 55204      9
# 67799      4
# 7457       7
# 76005     10
# 35765    382
# 36050    364
# 371     1090
# 53508    737
# 41606     83
# 36042    366
# 37127    305
# 55066    640
# 24813    754
# 53919    712
# 35911    373
# 8505    1480
# 21502    676
# 33519    516
# 33766    505
# 31560    611
# 35600    398

# %%
categorization.get_users_head()
# Out:
#                      n_ratings  n_reviews                     uid  \
# __null_dask_index__
# 0                         7820        465          nmann08.184925
# 1                         2521       2504      stjamesgate.163714
# 2                         1797       1143           mdagnew.19527
# 3                           31         31   helloloser12345.10867
# 4                          604        604         cypressbob.3708
# 5                         2326          0         hellpop65.48993
# 6                         3098          0          latarnik.52897
# 7                         1866         23   rochefortchris.697017
# 8                         1131        188       okcnittany.144868
# 9                         9987         16           jaydoc.265507
# 10                        4078        127            ejimhof.5743
# 11                        2329          5  graduatedcashew.730089
# 12                         264         95     brewdude1982.691169
# 13                        2314       1990       agentmunky.409755
# 14                         154          0     swungomonkey.698859
# 15                         732         14            byofb.537281
# 16                          16          1        cadensdad.704691
# 17                         585        389        ferrari29.320392
# 18                          10          0       samurai221.575106
# 19                        1315       1315       othershoe2.233642
# 20                         231          0    friedgold2112.672227
# 21                        6306       6306           brentk56.6284
# 22                        6260       4734         emerge077.17949
# 23                        1851         10           buckyp.435592
# 24                        3758       3562   garthdanielson.522584
# 25                         187          1   poopsmitherson.468246
# 26                        1489        355         animal69.160100
# 27                        5347       5199        chinchill.199175
# 28                        2439       1372         barnzy78.224763
# 29                           1          1          brettmc.615627
#
#                             username              joined  \
# __null_dask_index__
# 0                            nmann08 2008-01-07 11:00:00
# 1                        StJamesGate 2007-10-08 10:00:00
# 2                            mdagnew 2005-05-18 10:00:00
# 3                    helloloser12345 2004-11-25 11:00:00
# 4                         cypressbob 2003-11-20 11:00:00
# 5                          Hellpop65 2005-11-14 11:00:00
# 6                           Latarnik 2005-12-02 11:00:00
# 7                     RochefortChris 2012-10-02 10:00:00
# 8                         OKCNittany 2007-06-25 10:00:00
# 9                             jaydoc 2008-11-12 11:00:00
# 10                           ejimhof 2004-04-12 10:00:00
# 11                   GraduatedCashew 2013-04-25 10:00:00
# 12                      brewdude1982 2012-08-24 10:00:00
# 13                        AgentMunky 2009-12-29 11:00:00
# 14                      swungomonkey 2012-10-13 10:00:00
# 15                             BYOFB 2010-12-11 11:00:00
# 16                         CadensDad 2012-11-24 11:00:00
# 17                         ferrari29 2009-04-15 10:00:00
# 18                        samurai221 2011-03-03 11:00:00
# 19                        OtherShoe2 2008-07-09 10:00:00
# 20                     FriedGold2112 2012-04-12 10:00:00
# 21                          brentk56 2004-05-13 10:00:00
# 22                         emerge077 2005-04-16 10:00:00
# 23                            buckyp 2010-03-07 11:00:00
# 24                    GarthDanielson 2010-11-06 11:00:00
# 25                    poopsmitherson 2010-06-10 10:00:00
# 26                          animal69 2007-09-21 10:00:00
# 27                         chinchill 2008-02-29 11:00:00
# 28                          barnzy78 2008-06-02 10:00:00
# 29                           BrettMc 2011-08-12 10:00:00
#
#                                           location           country
# __null_dask_index__
# 0                        United States, Washington     United States
# 1                          United States, New York     United States
# 2                                 Northern Ireland  Northern Ireland
# 3                                 Northern Ireland  Northern Ireland
# 4                                 Northern Ireland  Northern Ireland
# 5                            United States, Kansas     United States
# 6                        United States, New Jersey     United States
# 7                    United States, North Carolina     United States
# 8                          United States, Oklahoma     United States
# 9                            United States, Kansas     United States
# 10                     United States, Pennsylvania     United States
# 11                       United States, California     United States
# 12                   United States, North Carolina     United States
# 13                         United States, New York     United States
# 14                                            None              None
# 15                        United States, Wisconsin     United States
# 16                     United States, Pennsylvania     United States
# 17                         United States, Illinois     United States
# 18                         United States, Virginia     United States
# 19                    United States, Massachusetts     United States
# 20                                            None              None
# 21                   United States, North Carolina     United States
# 22                         United States, Illinois     United States
# 23                   United States, South Carolina     United States
# 24                         United States, Virginia     United States
# 25                          United States, Georgia     United States
# 26                        United States, Louisiana     United States
# 27                   United States, South Carolina     United States
# 28                         United States, Illinois     United States
# 29                          United States, Georgia     United States

# %%
categorization.get_beers_head()
# Out:
#     bid  n_ratings  avg_rating  ba_score  std_rating
# 0     3          3    4.106667       NaN    0.228813
# 1     4         10    3.639000      84.0    0.574708
# 2     5       1538    3.441203      78.0    0.554967
# 3     6       2660    3.657617      82.0    0.485640
# 4     7       2977    3.265694      74.0    0.631811
# 5     8        132    3.290682      77.0    0.581732
# 6     9        215    3.172698      74.0    0.557561
# 7    10       1608    3.807351      86.0    0.426868
# 8    11         80    3.305125      78.0    0.474257
# 9    12         83    3.744217      85.0    0.478819
# 10   13         83    3.125783      76.0    0.538517
# 11   14        243    3.744938      84.0    0.493320
# 12   15        152    3.665658      83.0    0.420286
# 13   16         12    3.831667      84.0    0.354726
# 14   17       1941    3.314044      75.0    0.546628
# 15   18         10    3.432000      83.0    0.380100
# 16   19        638    4.039373      90.0    0.468764
# 17   20         46    4.001956      87.0    0.401457
# 18   21         59    4.250000      90.0    0.398357
# 19   23        272    3.680919      84.0    0.436137
# 20   24        145    3.781655      85.0    0.403751
# 21   26        155    3.463161      80.0    0.395156
# 22   27         91    3.339011      79.0    0.443361
# 23   28          1    3.450000       NaN    0.000000
# 24   29        146    2.939110      71.0    0.425650
# 25   30       4582    4.233433      94.0    0.453167
# 26   31       2241    3.894257      87.0    0.434255
# 27   32        430    4.032000      89.0    0.394362
# 28   33       4233    4.199608      93.0    0.437685
# 29   34       9123    4.318108      96.0    0.482291

# %%
user_ids = categorization.get_userIds_list()
print(len(user_ids))
user_ids[:3]
# Out:
# 153704
# ['nmann08.184925', 'stjamesgate.163714', 'mdagnew.19527']

# %%
categorization.categorize_all_users()
len(categorization.users_ddf[categorization.users_ddf["is_exp"] == 1].index)
# Out:
# /home/juliette/Documents/EPFL/Ada/Ada_project/3/ada-2022-project-analyteam/categories.py:153: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   quantile = self.users_ddf.quantile(0.9)
# 15371

# %%
REFINED_DATA = "RefinedData"
import ingestion as ing

categorization.users_ddf.to_parquet(ing.build_path(folderind="ba", filename="users", ext=".parquet", basepath=ing.REFINED_PATH))
# Out:
# /home/juliette/Documents/EPFL/Ada/Ada_project/3/ada-2022-project-analyteam/categories.py:153: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   quantile = self.users_ddf.quantile(0.9)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 5
#       2 import ingestion as ing
#       4 categorization.categorize_all_users()
# ----> 5 categorization.users_ddf.to_parquet(ing.build_path(folderind="ba", filename="users", ext=".parquet", basepath=ing.REFINED_PATH))
#       6 categorization.users_ddf
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:2975, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2888 """
#    2889 Write a DataFrame to the binary parquet format.
#    2890
#    (...)
#    2971 >>> content = f.read()
#    2972 """
#    2973 from pandas.io.parquet import to_parquet
# -> 2975 return to_parquet(
#    2976     self,
#    2977     path,
#    2978     engine,
#    2979     compression=compression,
#    2980     index=index,
#    2981     partition_cols=partition_cols,
#    2982     storage_options=storage_options,
#    2983     **kwargs,
#    2984 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parquet.py:430, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     426 impl = get_engine(engine)
#     428 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 430 impl.write(
#     431     df,
#     432     path_or_buf,
#     433     compression=compression,
#     434     index=index,
#     435     partition_cols=partition_cols,
#     436     storage_options=storage_options,
#     437     **kwargs,
#     438 )
#     440 if path is None:
#     441     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parquet.py:312, in FastParquetImpl.write(self, df, path, compression, index, partition_cols, storage_options, **kwargs)
#     307     raise ValueError(
#     308         "storage_options passed with file object or non-fsspec file path"
#     309     )
#     311 with catch_warnings(record=True):
# --> 312     self.api.write(
#     313         path,
#     314         df,
#     315         compression=compression,
#     316         write_index=index,
#     317         partition_on=partition_cols,
#     318         **kwargs,
#     319     )
#
# File ~/.local/lib/python3.10/site-packages/fastparquet/writer.py:1220, in write(filename, data, row_group_offsets, compression, file_scheme, open_with, mkdirs, has_nulls, write_index, partition_on, fixed_text, append, object_encoding, times, custom_metadata, stats)
#    1217 check_column_names(data.columns, partition_on, fixed_text,
#    1218                    object_encoding, has_nulls)
#    1219 ignore = partition_on if file_scheme != 'simple' else []
# -> 1220 fmd = make_metadata(data, has_nulls=has_nulls, ignore_columns=ignore,
#    1221                     fixed_text=fixed_text,
#    1222                     object_encoding=object_encoding,
#    1223                     times=times, index_cols=index_cols,
#    1224                     partition_cols=partition_on)
#    1225 if custom_metadata is not None:
#    1226     kvm = fmd.key_value_metadata or []
#
# File ~/.local/lib/python3.10/site-packages/fastparquet/writer.py:826, in make_metadata(data, has_nulls, ignore_columns, fixed_text, object_encoding, times, index_cols, partition_cols)
#     824     se.name = column
#     825 else:
# --> 826     se, type = find_type(data[column], fixed_text=fixed,
#     827                          object_encoding=oencoding, times=times,
#     828                          is_index=is_index)
#     829 col_has_nulls = has_nulls
#     830 if has_nulls is None:
#
# File ~/.local/lib/python3.10/site-packages/fastparquet/writer.py:126, in find_type(data, fixed_text, object_encoding, times, is_index)
#     124 elif dtype == "O":
#     125     if object_encoding == 'infer':
# --> 126         object_encoding = infer_object_encoding(data)
#     128     if object_encoding == 'utf8':
#     129         type, converted_type, width = (parquet_thrift.Type.BYTE_ARRAY,
#     130                                        parquet_thrift.ConvertedType.UTF8,
#     131                                        None)
#
# File ~/.local/lib/python3.10/site-packages/fastparquet/writer.py:344, in infer_object_encoding(data)
#     342     return 'float'
#     343 else:
# --> 344     raise ValueError("Can't infer object conversion type: %s" % head)
#
# ValueError: Can't infer object conversion type: 0    2008-01-07 11:00:00
# 1    2007-10-08 10:00:00
# 2    2005-05-18 10:00:00
# 3    2004-11-25 11:00:00
# 4    2003-11-20 11:00:00
# 5    2005-11-14 11:00:00
# 6    2005-12-02 11:00:00
# 7    2012-10-02 10:00:00
# 8    2007-06-25 10:00:00
# 9    2008-11-12 11:00:00
# Name: joined, dtype: object

# %%
categorization.

# %%
from copy import copy
import dask.dataframe as ddf
T = 3

ratings_ddf = copy(categorization.ratings_ddf)
beers_per_users = copy(categorization.beers_per_users)
users_ddf = copy(categorization.users_ddf)

adventurer_score_fast_table=categorization.ratings_ddf.loc[categorization.ratings_ddf["dated_rating"] < T].copy().groupby('uid').count()[['rank']]
adventurer_score_fast_table=adventurer_score_fast_table.reset_index()

users_ddf=ddf.merge(
                users_ddf,
                adventurer_score_fast_table,
                how="left", on='uid')
users_ddf=users_ddf.rename(columns={'rank': 'adv_score'}).fillna(0)
users_ddf['adv_score'] = users_ddf['adv_score'].astype('Int64')
users_ddf

# %%
T = 3
n = 240
import numpy as np

def jupyter_get_adventurer_score(user_ids, ratings_ddf, beers_per_users):
    print("ADVENTURER SCORE FOR ", user_id)
    rating_of_user_dated = ratings_ddf.loc[ratings_ddf["uid"] == user_id][["dated_rating"]]
    rating_of_user_dated = ratings_ddf.groupby("uid").apply(list)
    
    rating_of_user_dated = rating_of_user_dated.loc[rating_of_user_dated["dated_rating"] < T]
    return len(rating_of_user_dated.index)

# %%
T = 3
n = 240
import numpy as np

def jupyter_get_adventurer_score(user_id, ratings_ddf, beers_per_users):
    #print("ADVENTURER SCORE FOR ", user_id)
    #t = time.time()
    rating_of_user_dated = ratings_ddf.loc[ratings_ddf["dated_rating"] < T]
    #print("line 1", time.time()-t)

    #t = time.time()
    rating_of_user_dated = rating_of_user_dated.loc[rating_of_user_dated["uid"] == user_id][["dated_rating"]]
    #print("line 2", time.time()-t)
    return len(rating_of_user_dated.index)

# %%
t = time.time()
n = 100
for user_id in user_ids[:n]:
    jupyter_get_adventurer_score(user_id, categorization.ratings_ddf, categorization.beers_per_users)
print((time.time()-t) / n)

# %%
t = time.time()
jupyter_get_adventurer_score("jarodrishe.823911", categorization.ratings_ddf, categorization.beers_per_users)
print(time.time()-t)

# %%
categorization.beers_ddf.loc[categorization.beers_ddf["bid"] == 17538]

# %%
from copy import copy
#(ba_score+mean(avg_ratings)-mean(ba_score))/std(ba_score)4.054117*std(avf_ratings)0.385004

categorization.beers_ddf.loc[~np.isnan(categorization.beers_ddf["ba_score"])]["ba_score"]

beers_ddf = copy(categorization.beers_ddf)
beers_ddf["ba_score"] /= 20
beers_ddf

# %%
def jupyter_get_explorer_score_for_user(ratings_ddf, user_id, beers_per_users):
    first_ratings = ratings_ddf.loc[ratings_ddf["rank"] <= 10][["uid"]]
    first_ratings = first_ratings.loc[first_ratings["uid"] == user_id]
    return len(first_ratings.index)

# %%
from copy import copy

ratings_ddf = copy(categorization.ratings_ddf)
beers_per_users = copy(categorization.beers_per_users)

t = time.time()
n = 10
for user_id in user_ids[:n]:
    print("user id :",user_id,"score:",jupyter_get_explorer_score_for_user(ratings_ddf, user_id, beers_per_users))
print("Total time average: ", (time.time() - t)/n)

jupyter_get_explorer_score_for_user(ratings_ddf, "zymurgy4all.11427", beers_per_users)

# %%
def jupyter_get_explorer_score(ratings_ddf, user_ids3, beers_per_users):
    grouped_ratings_dff = ratings_ddf.groupby("uid").apply(list)
    
    
    first_ratings = ratings_ddf.loc[ratings_ddf["rank"] <= 10][["uid"]]
    first_ratings = first_ratings.loc[first_ratings["uid"] == user_id]
    return len(first_ratings.index)

# %%
from copy import copy
import dask.dataframe as ddf

ratings_ddf = copy(categorization.ratings_ddf)
beers_per_users = copy(categorization.beers_per_users)
users_ddf = copy(categorization.users_ddf)

grouped_ratings_ddf = ratings_ddf[["uid","rank"]]
grouped_ratings_ddf = grouped_ratings_ddf.loc[grouped_ratings_ddf["rank"]<=10].groupby("uid").count()

grouped_ratings_table = grouped_ratings_ddf.reset_index()

users_ddf = ddf.merge(
                users_ddf,
                grouped_ratings_table,
                how="left", on='uid')

users_ddf = users_ddf.rename(columns={'rank': 'xpl_score'}).fillna(0)
users_ddf['xpl_score'] = users_ddf['xpl_score'].astype('Int64')

print(users_ddf["xpl_score"])

users_ddf

# %%
def jupyter_get_expertlike_score(user_id, beers_per_users, beers_ddf, ratings_ddf):
    beer_ids = beers_per_users[user_id]
    ref = beers_ddf.loc[beers_ddf["bid"].isin(beer_ids)][["bid","ba_score"]]
    r_user_beers = ratings_ddf.loc[ratings_ddf["bid"].isin(beer_ids)]
    std = beers_ddf["std_rating"]
    print(std)

    return

# %%
from copy import copy

user_id = user_ids[0]

ratings_ddf = copy(categorization.ratings_ddf)
beers_ddf = copy(categorization.beers_ddf)
beers_per_users = copy(categorization.beers_per_users)
users_ddf = copy(categorization.users_ddf)


jupyter_get_expertlike_score(user_id, beers_per_users, beers_ddf, ratings_ddf)

# %%
conformist_table = ddf.merge(ratings_ddf, beers_ddf, how="inner", left_on="bid", right_on="bid")
conformist_table=conformist_table[conformist_table['std_rating']!=0]

conformist_table['cfm_per_rating'] = ((conformist_table['rating']-conformist_table['avg_rating'])/conformist_table['std_rating'])**2
conformist_table=conformist_table.groupby('uid').mean()['cfm_per_rating'].reset_index(
    
users_ddf=ddf.merge(users_ddf, conformist_table, how="left", on='uid')
user_ddf=users_ddf.rename(columns={'cfm_per_rating': 'cfm_score'})

# %%
df =pd.DataFrame(data={'id':[111,111,111,333,444],'user_id':[11,22,33,44,55],'date': [10,1, 2,9,8], 'rating': [0,1, 1,5,6]}) 
df

# %%
df.loc[df["id"] == 111][["user_id","date"]].sort_values("date")

# %%
df.loc[df["id"] == 111].loc[df["rating"] == 1]

# %%
type(df["col1"][0])
